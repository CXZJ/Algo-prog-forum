# %% [markdown]
# forum task 1

# %%
lloyd = {
 "name": "Lloyd",
 "homework": [90.0,97.0,75.0,92.0],
 "quizzes": [88.0,40.0,94.0],
 "tests": [75.0,90.0]
}
alice = {
 "name": "Alice",
 "homework": [100.0, 92.0, 98.0, 100.0],
 "quizzes": [82.0, 83.0, 91.0],
 "tests": [89.0, 97.0]
}
tyler = {
 "name": "Tyler",
 "homework": [0.0, 87.0, 75.0, 22.0],
 "quizzes": [0.0, 75.0, 78.0],
 "tests": [100.0, 100.0]
}

students = [lloyd, alice, tyler]

print(students)

def average(numbers):
    total = float(sum(numbers))
    return (total/len(numbers))

def get_average(student):
    homework = average(student['homework'])
    quizzes = average(student['quizzes'])
    tests = average(student['tests'])
    
    return (homework*0.1 + quizzes*0.3 + tests*0.6)

def get_letter_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'F'


print(get_letter_grade(get_average(lloyd)))

def get_class_average(students):
    results = []
    for i in range(len(students)):
        results.append(get_average(students[i]))
    return average(results)

print(get_class_average(students))
print(get_letter_grade(get_class_average(students)))
# Out:
# [{'name': 'Lloyd', 'homework': [90.0, 97.0, 75.0, 92.0], 'quizzes': [88.0, 40.0, 94.0], 'tests': [75.0, 90.0]}, {'name': 'Alice', 'homework': [100.0, 92.0, 98.0, 100.0], 'quizzes': [82.0, 83.0, 91.0], 'tests': [89.0, 97.0]}, {'name': 'Tyler', 'homework': [0.0, 87.0, 75.0, 22.0], 'quizzes': [0.0, 75.0, 78.0], 'tests': [100.0, 100.0]}]
# B
# 83.86666666666666
# B

# %% [markdown]
# Forum task 2

# %%
k1 = ('COP 2510')
k2 = ('EGN 3000L')
k3 = ('MAC 2281')
k4 = ('MUH 3016')
k5 = ('PHY 2048')

course_names = {
    k1 : 'Programming Concepts',
    k2 : 'Foundations of Engineering Lab',
    k3 : 'Calculus I',
    k4 : 'Survey of Jazz',
    k5 : 'General Physics I'
}

course_Instructors = {
    k1 : 'Z. Beasley',
    k2 : 'J. Anderson',
    k3 : 'A. Makaryus',
    k4 : 'A. Wilkins',
    k5 : 'G. Pradhan'
}

course_Times = {
    k1 : 'MW 12:30pm – 1:45pm',
    k2 : 'TR 11:00am – 12:15pm',
    k3 : 'MW 9:30am – 10:45am',
    k4 : 'online asynchronous',
    k5 : 'TR 5:00pm – 6:15pm'
}

course_Choice = input('Enter a course number: ')

if course_Choice == k1:
    print(f'''the course details are: 
          Course Name: {course_names[k1]}
          Concepts Intstructor: {course_Instructors[k1]}
          Class Times: {course_Times[k1]}''')
elif course_Choice == k2:
    print(f'''the course details are: 
          Course Name: {course_names[k2]}
          Concepts Intstructor: {course_Instructors[k2]}
          Class Times: {course_Times[k2]}''')
elif course_Choice == k3:
    print(f'''the course details are: 
          Course Name: {course_names[k3]}
          Concepts Intstructor: {course_Instructors[k3]}
          Class Times: {course_Times[k3]}''')
elif course_Choice == k4:
    print(f'''the course details are: 
          Course Name: {course_names[k4]}
          Concepts Intstructor: {course_Instructors[k4]}
          Class Times: {course_Times[k4]}''')
elif course_Choice == k5:
    print(f'''the course details are: 
          Course Name: {course_names[k5]}
          Concepts Intstructor: {course_Instructors[k5]}
          Class Times: {course_Times[k5]}''')
else:
    print(f'{course_Choice} is an invalid course number.')
# Out:
#  is an invalid course number.

# %%
Forum Task 3

# %%
weekdays = ('Sunday','Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday')
sales_total = []


for i in range(len(weekdays)):

  while True:
    try:
      sales = float(input(f'Enter sales for {weekdays[i]}: '))
      while sales < 0:
        sales = float(input(f'Input was invalid. Re-enter the sales for {weekdays[i]}: '))
      else:
        sales_total.append(sales)
        break

    except ValueError:
      while True:
        try:
          sales = float(input(f'Input was invalid. Re-enter the sales for {weekdays[i]}: '))
          while sales < 0:
            sales = float(input(f'Input was invalid. Re-enter the sales for {weekdays[i]}: '))
          else:
            sales_total.append(sales)
            break
        except ValueError:
          continue
        else:
          break
    else:
      break

print('The total sales is: ' + '$' + format(sum(sales_total), ',.2f'))
print('The minimum sale amount was: ' + '$' + format(min(sales_total), ',.2f') + ' The maximum sale amount was: ' + '$' + format(max(sales_total), ',.2f'))
# Out:
# The total sales is: $10,082.00
# The minimum sale amount was: $560.00 The maximum sale amount was: $3,010.00

# %% [markdown]
# Forum Task 4

# %%
morse_code = (' ', '--..--', '.-.-.-', '..--..', '-----', '.----', '..---', '...--', '....-', '.....', '-....', '--...', '---..', '----.','.-', '-...', '-.-.', '-..', '.', '..-.', '--.', '....', '..', '.---', '-.-', '.-..', '--', '-.', '---', '.--.', '--.-', '.-.', '...', '-', '..-', '...-', '.--', '-..-', '-.--', '--..')

userInput = str(input('Enter the string to be converted to Morse code: '))
sentence = list(userInput)

morse_code_sentence = []

def listToString(s):
    str1 = ""
    for ele in s:
        str1 += ele
 
    return str1


for i in range(len(sentence)):

    if sentence[i] == ' ':
        morse_code_sentence.append(morse_code[0])
    elif sentence[i] == ',':
        morse_code_sentence.append(morse_code[1])
    elif sentence[i] == '.':
        morse_code_sentence.append(morse_code[2])
    elif sentence[i] == '?':
        morse_code_sentence.append(morse_code[3])
    elif sentence[i] == '0':
        morse_code_sentence.append(morse_code[4])
    elif sentence[i] == '1':
        morse_code_sentence.append(morse_code[5])
    elif sentence[i] == '2':
        morse_code_sentence.append(morse_code[6])
    elif sentence[i] == '3':
        morse_code_sentence.append(morse_code[7])
    elif sentence[i] == '4':
        morse_code_sentence.append(morse_code[8])
    elif sentence[i] == '5':
        morse_code_sentence.append(morse_code[9])
    elif sentence[i] == '6':
        morse_code_sentence.append(morse_code[10])
    elif sentence[i] == '7':
        morse_code_sentence.append(morse_code[11])
    elif sentence[i] == '8':
        morse_code_sentence.append(morse_code[12])
    elif sentence[i] == '9':
        morse_code_sentence.append(morse_code[13])
    elif sentence[i] == 'a':
        morse_code_sentence.append(morse_code[14])
    elif sentence[i] == 'b':
        morse_code_sentence.append(morse_code[15])
    elif sentence[i] == 'c':
        morse_code_sentence.append(morse_code[16])
    elif sentence[i] == 'd':
        morse_code_sentence.append(morse_code[17])
    elif sentence[i] == 'e':
        morse_code_sentence.append(morse_code[18])
    elif sentence[i] == 'f':
        morse_code_sentence.append(morse_code[19])
    elif sentence[i] == 'g':
        morse_code_sentence.append(morse_code[20])
    elif sentence[i] == 'h':
        morse_code_sentence.append(morse_code[21])
    elif sentence[i] == 'i':
        morse_code_sentence.append(morse_code[22])
    elif sentence[i] == 'j':
        morse_code_sentence.append(morse_code[23])
    elif sentence[i] == 'k':
        morse_code_sentence.append(morse_code[24])
    elif sentence[i] == 'l':
        morse_code_sentence.append(morse_code[25])
    elif sentence[i] == 'm':
        morse_code_sentence.append(morse_code[26])
    elif sentence[i] == 'n':
        morse_code_sentence.append(morse_code[27])
    elif sentence[i] == 'o':
        morse_code_sentence.append(morse_code[28])
    elif sentence[i] == 'p':
        morse_code_sentence.append(morse_code[29])
    elif sentence[i] == 'q':
        morse_code_sentence.append(morse_code[30])
    elif sentence[i] == 'r':
        morse_code_sentence.append(morse_code[31])
    elif sentence[i] == 's':
        morse_code_sentence.append(morse_code[32])
    elif sentence[i] == 't':
        morse_code_sentence.append(morse_code[33])
    elif sentence[i] == 'u':
        morse_code_sentence.append(morse_code[34])
    elif sentence[i] == 'v':
        morse_code_sentence.append(morse_code[35])
    elif sentence[i] == 'w':
        morse_code_sentence.append(morse_code[36])
    elif sentence[i] == 'x':
        morse_code_sentence.append(morse_code[37])
    elif sentence[i] == 'y':
        morse_code_sentence.append(morse_code[38])
    else:
        morse_code_sentence.append(morse_code[39])
    

print(listToString(morse_code_sentence))
# Out:
# .--.....-- ..... -..... --..--...-.--. ---..-. .-......-..
